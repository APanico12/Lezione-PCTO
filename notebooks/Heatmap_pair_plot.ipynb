# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    'Stock_A_Return': [0.12, 0.15, 0.08, 0.10, 0.09, 0.16, 0.11, 0.13, 0.07, 0.18],
    'Stock_B_Return': [0.10, 0.12, 0.07, 0.08, 0.14, 0.09, 0.13, 0.16, 0.11, 0.15],
    'Bond_Return': [0.03, 0.04, 0.02, 0.05, 0.04, 0.03, 0.06, 0.05, 0.02, 0.07],
    'Risk_Free_Rate': [0.01, 0.02, 0.01, 0.01, 0.01, 0.02, 0.01, 0.02, 0.01, 0.02],
    'Inflation': [0.02, 0.03, 0.02, 0.04, 0.03, 0.02, 0.03, 0.04, 0.03, 0.04]
})
data.head()
# Out:
#    Stock_A_Return  Stock_B_Return  Bond_Return  Risk_Free_Rate  Inflation
# 0            0.12            0.10         0.03            0.01       0.02
# 1            0.15            0.12         0.04            0.02       0.03
# 2            0.08            0.07         0.02            0.01       0.02
# 3            0.10            0.08         0.05            0.01       0.04
# 4            0.09            0.14         0.04            0.01       0.03

# %%
# Calculating the correlation matrix
correlation_matrix = data.corr()

# Displaying the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                 Stock_A_Return  Stock_B_Return  Bond_Return  Risk_Free_Rate  \
# Stock_A_Return        1.000000        0.361488     0.539369        0.859705
# Stock_B_Return        0.361488        1.000000     0.628808        0.426401
# Bond_Return           0.539369        0.628808     1.000000        0.336332
# Risk_Free_Rate        0.859705        0.426401     0.336332        1.000000
# Inflation             0.188794        0.584307     0.736321        0.263523
#
#                 Inflation
# Stock_A_Return   0.188794
# Stock_B_Return   0.584307
# Bond_Return      0.736321
# Risk_Free_Rate   0.263523
# Inflation        1.000000

# %%
# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plotting pairwise relationships using pairplot
sns.pairplot(data)
plt.suptitle('Pairwise Relationships Between Financial Variables', y=1.02)
plt.show()
